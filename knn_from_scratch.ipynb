# %%
import numpy as np

# %% [markdown]
# ## Algorithm: kNN

# %% [markdown]
# # Writing Algorithm from Scratch

# %%
class KNN:
    def __init__(self, k = 5):
        self.k = k

    def fit(self, X, y):
        """
        Fit the kNN model using X as training data and y as target values

        For kNN we just save those values so we can use them later in the predict function
        Args:
            X: training data
            y: training labels
        
        Returns:
            None
        """
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        """
        Predict the target values for the provided data (classes of the input data)

        Args:
            X: data to predict the target values for. Shape (n_samples, n_features)

        Returns:
            List<Obj>: predicted class labels for the input data points using kNN
        """

        return np.array([self._predict(x) for x in X])
    
    def _predict(self, X):
        """
        Predict the target value for a single data point

        Args:
            X: data to predict the target value for. Shape (n_features,)

        Returns:
            Obj: predicted class label for the input data point using kNN
        """

        # calculate distances from training data

        # find k-nearest neighbors and their labels

        # get a majority vote (most common class label) and return it

# %% [markdown]
# # Testing Algorithm

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

cmap = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
iris_data = datasets.load_iris()
X, y = iris_data.data, iris_data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=109)

print([X_train.shape, y_train.shape, X_test.shape, y_test.shape])
# Out:
# [(120, 4), (120,), (30, 4), (30,)]

# %%
# explore iris_data
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c = y, cmap = cmap, edgecolor='k', s=20)
plt.title('Iris Data Scatter Plot (Sepal Length vs Sepal Width)')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# legend
legend_labels = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
legend_handles = [Patch(color=cmap(i), label=legend_labels[i]) for i in range(3)]
plt.legend(handles=legend_handles)

plt.show()
